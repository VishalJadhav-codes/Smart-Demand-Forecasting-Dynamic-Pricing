# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("C:\Projects\Smart Demand Forecasting & Dynamic Pricing Recommendation System\data\smart_demand_pricing_dataset.csv")

# View first few rows
print(df.head())
# Out:
#          date  price  discount  units_sold  revenue
# 0  2023-01-01    902        20           1      721
# 1  2023-01-02   1235        15           3     3149
# 2  2023-01-03   1070         0           1     1070
# 3  2023-01-04    906         0           1      906
# 4  2023-01-05    871         5           8     6619

# %% [markdown]
# # Basic Data Understanding

# %%
df.shape
# Out:
# (731, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        731 non-null    object
#  1   price       731 non-null    int64
#  2   discount    731 non-null    int64
#  3   units_sold  731 non-null    int64
#  4   revenue     731 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 28.7+ KB

# %%
df.describe()
# Out:
#              price    discount  units_sold       revenue
# count   731.000000  731.000000  731.000000    731.000000
# mean   1150.742818    9.644323    4.105335   4183.670315
# std     208.437007    7.120059    3.556374   3693.785819
# min     800.000000    0.000000    1.000000    646.000000
# 25%     966.500000    5.000000    1.000000   1167.000000
# 50%    1157.000000   10.000000    3.000000   2919.000000
# 75%    1320.500000   15.000000    6.000000   6264.500000
# max    1499.000000   20.000000   20.000000  21872.000000

# %% [markdown]
# # Data Handelling

# %%
df['date'] = pd.to_datetime(df['date'])
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %% [markdown]
# # Visualizations

# %%
plt.figure()
plt.hist(df['units_sold'], bins=30)
plt.xlabel("units_sold")
plt.ylabel("Frequency")
plt.title("Distribution of Units Sold")
plt.show()

# %%
plt.figure()
plt.scatter(df['price'], df['units_sold'])
plt.xlabel('Price')
plt.ylabel('Units Sold')
plt.title('Price vs Demand')
plt.show()

# %%
plt.figure()
df.groupby('discount')['units_sold'].mean().plot(kind='bar')
plt.xlabel('Discount (%)')
plt.ylabel('Average Units Sold')
plt.title('Discount vs Average Demand')
plt.show()

# %% [markdown]
# # Correlation analysis

# %%
import numpy as np

correlation = df[['price', 'discount', 'units_sold', 'revenue']].corr()
correlation
# Out:
#                price  discount  units_sold   revenue
# price       1.000000  0.020628   -0.119015  0.090937
# discount    0.020628  1.000000    0.018252 -0.071701
# units_sold -0.119015  0.018252    1.000000  0.953704
# revenue     0.090937 -0.071701    0.953704  1.000000
